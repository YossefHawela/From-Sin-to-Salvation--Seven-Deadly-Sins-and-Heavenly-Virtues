# %% [markdown]
# <a href="https://colab.research.google.com/github/YossefHawela/From-Sin-to-Salvation--Seven-Deadly-Sins-and-Heavenly-Virtues/blob/main/Quantization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Quantization

# %%
from PIL import Image
import matplotlib.pyplot as plt


img = Image.open(image_path)
plt.imshow(img)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
image_path = 'img3.jpg'
bits = 1
quantize_image = img.convert('P', palette=Image.ADAPTIVE, colors=2**bits)

plt.imshow(quantize_image)
plt.title('Quantized Image')
plt.axis('off')
plt.show()
